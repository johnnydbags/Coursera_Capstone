# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


#!pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


#! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
from bs4 import BeautifulSoup
from IPython.display import Image 
from IPython.core.display import HTML 
from IPython.display import display_html

# %%
source = requests.get('https://www.census.gov/quickfacts/fact/table/goosecreekcitysouthcarolina,summervilletownsouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina/PST045219').text
soup=BeautifulSoup(source,'lxml')
print(soup.title)
from IPython.display import display_html
tab = str(soup.table)
display_html(tab,raw=True)
# Out:
# <title>U.S. Census Bureau QuickFacts: Goose Creek city, South Carolina; Summerville town, South Carolina; Charleston city, South Carolina; James Island town, South Carolina; North Charleston city, South Carolina; Mount Pleasant town, South Carolina</title>
# <table class="type" data-geospan="6">
# <colgroup>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# </colgroup>
# <tbody data-topic="">
# <tr class="qf-header qf-persist">
# <th scope="col"><select class="linear-arrow-t1" id="qf-topic-select"><option class="bold uppercase" value="all">All Topics</option>
# <option value="Population">Population</option>
# <option value="Age and Sex">Age and Sex</option>
# <option value="Race and Hispanic Origin">Race and Hispanic Origin</option>
# <option value="Population Characteristics">Population Characteristics</option>
# <option value="Housing">Housing</option>
# <option value="Families &amp; Living Arrangements">Families &amp; Living Arrangements</option>
# <option value="Computer and Internet Use">Computer and Internet Use</option>
# <option value="Education">Education</option>
# <option value="Health">Health</option>
# <option value="Economy">Economy</option>
# <option value="Transportation">Transportation</option>
# <option value="Income &amp; Poverty">Income &amp; Poverty</option>
# <option value="Businesses">Businesses</option>
# <option value="Geography">Geography</option></select></th>
# <th data-geoid="4529815" data-shortname="goosecreekcitysouthcarolina" scope="col"><div class="qf-geobox">
# <a class="quicklink icon-search" data-geoid="4529815" data-title="Goose Creek city, South Carolina" href="/quickfacts/quicklinks/4529815" title="Browse Quicklinks for Goose Creek city, South Carolina"></a><span>Goose Creek city, South Carolina</span><a class="removegeo icon-cancel-squared" data-facts="/PST045219" data-geos="/summervilletownsouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina" href="/quickfacts/fact/table/summervilletownsouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina/PST045219" title="Remove Goose Creek city, South Carolina"></a>
# </div></th>
# <th data-geoid="4570270" data-shortname="summervilletownsouthcarolina" scope="col"><div class="qf-geobox">
# <a class="quicklink icon-search" data-geoid="4570270" data-title="Summerville town, South Carolina" href="/quickfacts/quicklinks/4570270" title="Browse Quicklinks for Summerville town, South Carolina"></a><span>Summerville town, South Carolina</span><a class="removegeo icon-cancel-squared" data-facts="/PST045219" data-geos="/goosecreekcitysouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina" href="/quickfacts/fact/table/goosecreekcitysouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina/PST045219" title="Remove Summerville town, South Carolina"></a>
# </div></th>
# <th data-geoid="4513330" data-shortname="charlestoncitysouthcarolina" scope="col"><div class="qf-geobox">
# <a class="quicklink icon-search" data-geoid="4513330" data-title="Charleston city, South Carolina" href="/quickfacts/quicklinks/4513330" title="Browse Quicklinks for Charleston city, South Carolina"></a><span>Charleston city, South Carolina</span><a class="removegeo icon-cancel-squared" data-facts="/PST045219" data-geos="/goosecreekcitysouthcarolina,summervilletownsouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina" href="/quickfacts/fact/table/goosecreekcitysouthcarolina,summervilletownsouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina/PST045219" title="Remove Charleston city, South Carolina"></a>
# </div></th>
# <th data-geoid="4536430" data-shortname="jamesislandtownsouthcarolina" scope="col"><div class="qf-geobox">
# <a class="quicklink icon-search" data-geoid="4536430" data-title="James Island town, South Carolina" href="/quickfacts/quicklinks/4536430" title="Browse Quicklinks for James Island town, South Carolina"></a><span>James Island town, South Carolina</span><a class="removegeo icon-cancel-squared" data-facts="/PST045219" data-geos="/goosecreekcitysouthcarolina,summervilletownsouthcarolina,charlestoncitysouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina" href="/quickfacts/fact/table/goosecreekcitysouthcarolina,summervilletownsouthcarolina,charlestoncitysouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina/PST045219" title="Remove James Island town, South Carolina"></a>
# </div></th>
# <th data-geoid="4550875" data-shortname="northcharlestoncitysouthcarolina" scope="col"><div class="qf-geobox">
# <a class="quicklink icon-search" data-geoid="4550875" data-title="North Charleston city, South Carolina" href="/quickfacts/quicklinks/4550875" title="Browse Quicklinks for North Charleston city, South Carolina"></a><span>North Charleston city, South Carolina</span><a class="removegeo icon-cancel-squared" data-facts="/PST045219" data-geos="/goosecreekcitysouthcarolina,summervilletownsouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,mountpleasanttownsouthcarolina" href="/quickfacts/fact/table/goosecreekcitysouthcarolina,summervilletownsouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,mountpleasanttownsouthcarolina/PST045219" title="Remove North Charleston city, South Carolina"></a>
# </div></th>
# <th data-geoid="4548535" data-shortname="mountpleasanttownsouthcarolina" scope="col"><div class="qf-geobox">
# <a class="quicklink icon-search" data-geoid="4548535" data-title="Mount Pleasant town, South Carolina" href="/quickfacts/quicklinks/4548535" title="Browse Quicklinks for Mount Pleasant town, South Carolina"></a><span>Mount Pleasant town, South Carolina</span><a class="removegeo icon-cancel-squared" data-facts="/PST045219" data-geos="/goosecreekcitysouthcarolina,summervilletownsouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina" href="/quickfacts/fact/table/goosecreekcitysouthcarolina,summervilletownsouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina/PST045219" title="Remove Mount Pleasant town, South Carolina"></a>
# </div></th>
# </tr>
# <tr class="fact selected" data-mnemonic="PST045219" data-precision="0" data-unit="ABS" data-url="/quickfacts/fact/table/goosecreekcitysouthcarolina,summervilletownsouthcarolina,charlestoncitysouthcarolina,jamesislandtownsouthcarolina,northcharlestoncitysouthcarolina,mountpleasanttownsouthcarolina#">
# <td>
# <a class="quickinfo icon-info-circled-1" data-title="Population estimates, July 1, 2019,  (V2019)" href="/quickfacts/note/PST045219" tabindex="-1" title="Quick Info"></a><span>Population estimates, July 1, 2019,  (V2019)</span>
# </td>
# <td data-geoid="4529815" data-isnumeric="1" data-srcnote="false" data-value="43665">
# <span data-title="Goose Creek city, South Carolina"></span>43,665</td>
# <td data-geoid="4570270" data-isnumeric="1" data-srcnote="false" data-value="52549">
# <span data-title="Summerville town, South Carolina"></span>52,549</td>
# <td data-geoid="4513330" data-isnumeric="1" data-srcnote="false" data-value="137566">
# <span data-title="Charleston city, South Carolina"></span>137,566</td>
# <td data-geoid="4536430" data-isnumeric="1" data-srcnote="false" data-value="12109">
# <span data-title="James Island town, South Carolina"></span>12,109</td>
# <td data-geoid="4550875" data-isnumeric="1" data-srcnote="false" data-value="115382">
# <span data-title="North Charleston city, South Carolina"></span>115,382</td>
# <td data-geoid="4548535" data-isnumeric="1" data-srcnote="false" data-value="91684">
# <span data-title="Mount Pleasant town, South Carolina"></span>91,684</td>
# </tr>
# </tbody>
# </table>

# %%
#this table is a little quirky so I'm going to go old school and create a database based on the above
data = [['Goose Creek', 43665], ['Summerville', 52549], ['Charleston', 137566], ['James Island', 12109], ['North Charleston', 115382], ['Mount Pleasant', 91684]] 
  
# Create the pandas DataFrame 
dfpop = pd.DataFrame(data, columns = ['City', 'population']) 
  
# print dataframe. 
dfpop
# Out:
#                City  population
# 0       Goose Creek       43665
# 1       Summerville       52549
# 2        Charleston      137566
# 3      James Island       12109
# 4  North Charleston      115382
# 5    Mount Pleasant       91684

# %% [markdown]
# Okay, now we know the population of the surrounding cities.  We'll come back to this later.  For now, let's take a look at Breweries in the area.

# %%
CLIENT_ID = 'HR2D0FMEQRX3STCPEBUSF22P1Q41XSB4JMPFMJNT54AVYD1O' # your Foursquare ID
CLIENT_SECRET = 'IZYJKTD31AXEE2U2KDQ5GYPYIWRQQL3BX2M21ZMCVVQSDWJS' # your Foursquare Secret
ACCESS_TOKEN = 'V0TVPHPZNFARAPF24MUNVC43JN3KZDQGSIMTBVIRQM000TS5' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: HR2D0FMEQRX3STCPEBUSF22P1Q41XSB4JMPFMJNT54AVYD1O
# CLIENT_SECRET:IZYJKTD31AXEE2U2KDQ5GYPYIWRQQL3BX2M21ZMCVVQSDWJS

# %%
#picking randomm address that appears to be located roughly in the middle of Charleston
address = '584 King St, Charleston, SC 29403'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 32.793201 -79.941287

# %%
search_query = 'Brewery'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Brewery .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HR2D0FMEQRX3STCPEBUSF22P1Q41XSB4JMPFMJNT54AVYD1O&client_secret=IZYJKTD31AXEE2U2KDQ5GYPYIWRQQL3BX2M21ZMCVVQSDWJS&ll=32.793201,-79.941287&oauth_token=V0TVPHPZNFARAPF24MUNVC43JN3KZDQGSIMTBVIRQM000TS5&v=20180604&query=Brewery&radius=50000&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fecfaa5d3e79e09bcfe0370'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4f0516fc5c5c4a361a4a0668',
#     'name': 'Charleston Brewery',
#     'location': {'address': 'King Street',
#      'lat': 32.78823044160592,
#      'lng': -79.93777240736041,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.78823044160592,
#        'lng': -79.93777240736041}],
#      'distance': 643,
#      'postalCode': '29401',
#      'cc': 'US',
#      'city': 'Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['King Street', 'Charleston, SC 29401']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4e02736ee4cdbd9a51747908',
#     'name': 'Original Pub & Brewery Tours of Charleston',
#     'location': {'address': '235 E Bay St',
#      'lat': 32.78127032,
#      'lng': -79.92822769,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.78127032,
#        'lng': -79.92822769},
#       {'label': 'entrance', 'lat': 32.781695, 'lng': -79.92769}],
#      'distance': 1804,
#      'postalCode': '29401',
#      'cc': 'US',
#      'neighborhood': 'Downtown Charleston',
#      'city': 'Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['235 E Bay St', 'Charleston, SC 29401']},
#     'categories': [{'id': '56aa371be4b08b9a8d573520',
#       'name': 'Tour Provider',
#       'pluralName': 'Tour Providers',
#       'shortName': 'Tour Provider',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4dad9006cda1aece4a5b9f1e',
#     'name': 'Palmetto Brewing Company',
#     'location': {'address': '289 Huger Street',
#      'lat': 32.80122215567243,
#      'lng': -79.9456803364998,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.80122215567243,
#        'lng': -79.9456803364998},
#       {'label': 'entrance', 'lat': 32.801207, 'lng': -79.945633}],
#      'distance': 982,
#      'postalCode': '29403',
#      'cc': 'US',
#      'city': 'Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['289 Huger Street', 'Charleston, SC 29403']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '170470429'},
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '52e68055498e7ec32a01d706',
#     'name': "Edmund's Oast",
#     'location': {'address': '1081 Morrison Dr',
#      'lat': 32.81000949675056,
#      'lng': -79.94741743606454,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.81000949675056,
#        'lng': -79.94741743606454},
#       {'label': 'entrance', 'lat': 32.810038, 'lng': -79.947356}],
#      'distance': 1957,
#      'postalCode': '29403',
#      'cc': 'US',
#      'city': 'Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['1081 Morrison Dr', 'Charleston, SC 29403']},
#     'categories': [{'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'shortName': 'Gastropub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '451481552'},
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '57375ea2498eba786daf2fa2',
#     'name': 'Ghost Monkey Brewery',
#     'location': {'address': '522 Wando Ln',
#      'lat': 32.83551654075295,
#      'lng': -79.87377737354474,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.83551654075295,
#        'lng': -79.87377737354474},
#       {'label': 'entrance', 'lat': 32.835577, 'lng': -79.873712}],
#      'distance': 7879,
#      'postalCode': '29464',
#      'cc': 'US',
#      'city': 'Mt. Pleasant',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['522 Wando Ln', 'Mt. Pleasant, SC 29464']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4bae4692f964a520019c3be3',
#     'name': 'South inn brewery',
#     'location': {'lat': 32.84633755419461,
#      'lng': -79.93753743093627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.84633755419461,
#        'lng': -79.93753743093627}],
#      'distance': 5925,
#      'postalCode': '29407',
#      'cc': 'US',
#      'city': 'Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['Charleston, SC 29407']},
#     'categories': [],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '523374b611d2af47fc843347',
#     'name': 'Freehouse Brewery',
#     'location': {'address': '2895 Pringle St',
#      'lat': 32.84204993827695,
#      'lng': -80.0023979980426,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.84204993827695,
#        'lng': -80.0023979980426}],
#      'distance': 7890,
#      'postalCode': '29405',
#      'cc': 'US',
#      'city': 'North Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['2895 Pringle St', 'North Charleston, SC 29405']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '56e48850cd10fabb7c13fa05',
#     'name': 'Low Tide Brewery',
#     'location': {'address': '2863 Maybank Hwy',
#      'lat': 32.74129057749149,
#      'lng': -80.04152923822403,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.74129057749149,
#        'lng': -80.04152923822403}],
#      'distance': 11019,
#      'postalCode': '29455',
#      'cc': 'US',
#      'city': 'Johns Island',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['2863 Maybank Hwy', 'Johns Island, SC 29455']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4d72d87d5f0037041289e7a0',
#     'name': 'Kumbütt Brewery',
#     'location': {'address': '108 Elbow Cir',
#      'lat': 33.003341999999996,
#      'lng': -80.01330899999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.003341999999996,
#        'lng': -80.01330899999999},
#       {'label': 'entrance', 'lat': 33.003377, 'lng': -80.013403}],
#      'distance': 24341,
#      'postalCode': '29445',
#      'cc': 'US',
#      'city': 'Goose Creek',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['108 Elbow Cir', 'Goose Creek, SC 29445']},
#     'categories': [{'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'shortName': 'Beer Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4d60148e29ef236a59cda059',
#     'name': 'Gordon Biersch Brewery Restaurant',
#     'location': {'lat': 32.87515682999694,
#      'lng': -80.01157287768143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.87515682999694,
#        'lng': -80.01157287768143}],
#      'distance': 11245,
#      'cc': 'US',
#      'state': 'South Carolina',
#      'country': 'United States',
#      'formattedAddress': ['South Carolina']},
#     'categories': [{'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'shortName': 'Beer Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '553209fd498e7e82c981e351',
#     'name': 'Revelry Brewery',
#     'location': {'lat': 32.8908432,
#      'lng': -79.9880476,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.8908432,
#        'lng': -79.9880476}],
#      'distance': 11716,
#      'cc': 'US',
#      'city': 'Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['Charleston, SC']},
#     'categories': [],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4d4c814332a3236a11260cea',
#     'name': 'Westbrook Brewing Company',
#     'location': {'address': '510 Ridge Rd',
#      'lat': 32.84675565604862,
#      'lng': -79.87683506682515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.84675565604862,
#        'lng': -79.87683506682515},
#       {'label': 'entrance', 'lat': 32.846559, 'lng': -79.876936}],
#      'distance': 8479,
#      'postalCode': '29464',
#      'cc': 'US',
#      'city': 'Mt. Pleasant',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['510 Ridge Rd', 'Mt. Pleasant, SC 29464']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '58e8e4c3ebf02879e745aa7c',
#     'name': 'Fat Pig Brewery',
#     'location': {'address': '3690 State Rd S-10-1024',
#      'lat': 32.80287705216257,
#      'lng': -80.1149520277977,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.80287705216257,
#        'lng': -80.1149520277977}],
#      'distance': 16286,
#      'postalCode': '29455',
#      'cc': 'US',
#      'city': 'Johns Island',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['3690 State Rd S-10-1024',
#       'Johns Island, SC 29455']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4bc0cbedabf4952143e6bf93',
#     'name': 'COAST Brewing Company',
#     'location': {'address': '1250 N 2nd St',
#      'crossStreet': 'Old Navy Base',
#      'lat': 32.87344497799604,
#      'lng': -79.97203479122165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.87344497799604,
#        'lng': -79.97203479122165}],
#      'distance': 9384,
#      'postalCode': '29405',
#      'cc': 'US',
#      'city': 'North Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['1250 N 2nd St (Old Navy Base)',
#       'North Charleston, SC 29405']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '41420172'},
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4f32a19d19836c91c7ea9326',
#     'name': 'Hops Restaurant and Brewery',
#     'location': {'address': '7842 Rivers Ave',
#      'lat': 32.9481201171875,
#      'lng': -80.04076385498047,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 32.948043,
#        'lng': -80.040959},
#       {'label': 'display',
#        'lat': 32.9481201171875,
#        'lng': -80.04076385498047}],
#      'distance': 19593,
#      'postalCode': '29406',
#      'cc': 'US',
#      'city': 'North Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['7842 Rivers Ave', 'North Charleston, SC 29406']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '53ab3acc498ee6657b508362',
#     'name': 'backyard brewery',
#     'location': {'lat': 33.01586111546794,
#      'lng': -80.0123645648719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.01586111546794,
#        'lng': -80.0123645648719}],
#      'distance': 25661,
#      'cc': 'US',
#      'city': 'Goose Creek',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['Goose Creek, SC']},
#     'categories': [{'id': '4bf58dd8d48988d117941735',
#       'name': 'Beer Garden',
#       'pluralName': 'Beer Gardens',
#       'shortName': 'Beer Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4e8ba988775bb28051f65673',
#     'name': 'Southend Brewery',
#     'location': {'lat': 32.99956148241441,
#      'lng': -79.95645374460992,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.99956148241441,
#        'lng': -79.95645374460992}],
#      'distance': 23015,
#      'cc': 'US',
#      'city': 'Charleston',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['Charleston, SC']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '53cb54d3498ea26c6f0fadad',
#     'name': 'Motorboater Brewery',
#     'location': {'address': '413 Sablewood Dr',
#      'lat': 33.044338,
#      'lng': -79.85457,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.044338,
#        'lng': -79.85457},
#       {'label': 'entrance', 'lat': 33.044304, 'lng': -79.854519}],
#      'distance': 29106,
#      'postalCode': '29450',
#      'cc': 'US',
#      'city': 'Huger',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['413 Sablewood Dr', 'Huger, SC 29450']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '53f8b283498e4466790c8007',
#     'name': 'Oak Road Brewery',
#     'location': {'address': '108 E 3rd North St',
#      'lat': 33.02359463949881,
#      'lng': -80.1717746257782,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.02359463949881,
#        'lng': -80.1717746257782}],
#      'distance': 33492,
#      'postalCode': '29483',
#      'cc': 'US',
#      'city': 'Summerville',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['108 E 3rd North St', 'Summerville, SC 29483']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '4f499908e4b0605e43b724b7',
#     'name': '843 Brewery',
#     'location': {'lat': 32.988766,
#      'lng': -80.228801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.988766,
#        'lng': -80.228801}],
#      'distance': 34586,
#      'postalCode': '29483',
#      'cc': 'US',
#      'city': 'Summerville',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['Summerville, SC 29483']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False},
#    {'id': '55ee162c498e8a2e86a5a1ef',
#     'name': 'Red Gate Brewery',
#     'location': {'lat': 33.099674224853516,
#      'lng': -80.03675842285156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.099674224853516,
#        'lng': -80.03675842285156}],
#      'distance': 35262,
#      'cc': 'US',
#      'city': 'Moncks Corner',
#      'state': 'SC',
#      'country': 'United States',
#      'formattedAddress': ['Moncks Corner, SC']},
#     'categories': [{'id': '50327c8591d4c4b30a586d5d',
#       'name': 'Brewery',
#       'pluralName': 'Breweries',
#       'shortName': 'Brewery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1609366182',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-10-5acf500bf9ad>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                                        name  \
# 0  4f0516fc5c5c4a361a4a0668                          Charleston Brewery
# 1  4e02736ee4cdbd9a51747908  Original Pub & Brewery Tours of Charleston
# 2  4dad9006cda1aece4a5b9f1e                    Palmetto Brewing Company
# 3  52e68055498e7ec32a01d706                               Edmund's Oast
# 4  57375ea2498eba786daf2fa2                        Ghost Monkey Brewery
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1609366182    False
# 1  [{'id': '56aa371be4b08b9a8d573520', 'name': 'T...  v-1609366182    False
# 2  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1609366182    False
# 3  [{'id': '4bf58dd8d48988d155941735', 'name': 'G...  v-1609366182    False
# 4  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...  v-1609366182    False
#
#    location.address  location.lat  location.lng  \
# 0       King Street     32.788230    -79.937772
# 1      235 E Bay St     32.781270    -79.928228
# 2  289 Huger Street     32.801222    -79.945680
# 3  1081 Morrison Dr     32.810009    -79.947417
# 4      522 Wando Ln     32.835517    -79.873777
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 32.78823044160592...                643
# 1  [{'label': 'display', 'lat': 32.78127032, 'lng...               1804
# 2  [{'label': 'display', 'lat': 32.80122215567243...                982
# 3  [{'label': 'display', 'lat': 32.81000949675056...               1957
# 4  [{'label': 'display', 'lat': 32.83551654075295...               7879
#
#   location.postalCode location.cc location.city location.state  \
# 0               29401          US    Charleston             SC
# 1               29401          US    Charleston             SC
# 2               29403          US    Charleston             SC
# 3               29403          US    Charleston             SC
# 4               29464          US  Mt. Pleasant             SC
#
#   location.country                 location.formattedAddress  \
# 0    United States       [King Street, Charleston, SC 29401]
# 1    United States      [235 E Bay St, Charleston, SC 29401]
# 2    United States  [289 Huger Street, Charleston, SC 29403]
# 3    United States  [1081 Morrison Dr, Charleston, SC 29403]
# 4    United States    [522 Wando Ln, Mt. Pleasant, SC 29464]
#
#   location.neighborhood venuePage.id location.crossStreet
# 0                   NaN          NaN                  NaN
# 1   Downtown Charleston          NaN                  NaN
# 2                   NaN    170470429                  NaN
# 3                   NaN    451481552                  NaN
# 4                   NaN          NaN                  NaN

# %%
dataframe.shape
# Out:
# (21, 19)

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                           name     categories  \
# 0                           Charleston Brewery            Bar
# 1   Original Pub & Brewery Tours of Charleston  Tour Provider
# 2                     Palmetto Brewing Company        Brewery
# 3                                Edmund's Oast      Gastropub
# 4                         Ghost Monkey Brewery        Brewery
# 5                            South inn brewery           None
# 6                            Freehouse Brewery        Brewery
# 7                             Low Tide Brewery        Brewery
# 8                              Kumbütt Brewery    Beer Garden
# 9            Gordon Biersch Brewery Restaurant    Beer Garden
# 10                             Revelry Brewery           None
# 11                   Westbrook Brewing Company        Brewery
# 12                             Fat Pig Brewery        Brewery
# 13                       COAST Brewing Company        Brewery
# 14                 Hops Restaurant and Brewery           Food
# 15                            backyard brewery    Beer Garden
# 16                            Southend Brewery            Bar
# 17                         Motorboater Brewery        Brewery
# 18                            Oak Road Brewery        Brewery
# 19                                 843 Brewery        Brewery
# 20                            Red Gate Brewery        Brewery
#
#                     address        lat        lng  \
# 0               King Street  32.788230 -79.937772
# 1              235 E Bay St  32.781270 -79.928228
# 2          289 Huger Street  32.801222 -79.945680
# 3          1081 Morrison Dr  32.810009 -79.947417
# 4              522 Wando Ln  32.835517 -79.873777
# 5                       NaN  32.846338 -79.937537
# 6           2895 Pringle St  32.842050 -80.002398
# 7          2863 Maybank Hwy  32.741291 -80.041529
# 8             108 Elbow Cir  33.003342 -80.013309
# 9                       NaN  32.875157 -80.011573
# 10                      NaN  32.890843 -79.988048
# 11             510 Ridge Rd  32.846756 -79.876835
# 12  3690 State Rd S-10-1024  32.802877 -80.114952
# 13            1250 N 2nd St  32.873445 -79.972035
# 14          7842 Rivers Ave  32.948120 -80.040764
# 15                      NaN  33.015861 -80.012365
# 16                      NaN  32.999561 -79.956454
# 17         413 Sablewood Dr  33.044338 -79.854570
# 18       108 E 3rd North St  33.023595 -80.171775
# 19                      NaN  32.988766 -80.228801
# 20                      NaN  33.099674 -80.036758
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 32.78823044160592...       643      29401
# 1   [{'label': 'display', 'lat': 32.78127032, 'lng...      1804      29401
# 2   [{'label': 'display', 'lat': 32.80122215567243...       982      29403
# 3   [{'label': 'display', 'lat': 32.81000949675056...      1957      29403
# 4   [{'label': 'display', 'lat': 32.83551654075295...      7879      29464
# 5   [{'label': 'display', 'lat': 32.84633755419461...      5925      29407
# 6   [{'label': 'display', 'lat': 32.84204993827695...      7890      29405
# 7   [{'label': 'display', 'lat': 32.74129057749149...     11019      29455
# 8   [{'label': 'display', 'lat': 33.00334199999999...     24341      29445
# 9   [{'label': 'display', 'lat': 32.87515682999694...     11245        NaN
# 10  [{'label': 'display', 'lat': 32.8908432, 'lng'...     11716        NaN
# 11  [{'label': 'display', 'lat': 32.84675565604862...      8479      29464
# 12  [{'label': 'display', 'lat': 32.80287705216257...     16286      29455
# 13  [{'label': 'display', 'lat': 32.87344497799604...      9384      29405
# 14  [{'label': 'entrance', 'lat': 32.948043, 'lng'...     19593      29406
# 15  [{'label': 'display', 'lat': 33.01586111546794...     25661        NaN
# 16  [{'label': 'display', 'lat': 32.99956148241441...     23015        NaN
# 17  [{'label': 'display', 'lat': 33.044338, 'lng':...     29106      29450
# 18  [{'label': 'display', 'lat': 33.02359463949881...     33492      29483
# 19  [{'label': 'display', 'lat': 32.988766, 'lng':...     34586      29483
# 20  [{'label': 'display', 'lat': 33.09967422485351...     35262        NaN
#
#     cc              city           state        country  \
# 0   US        Charleston              SC  United States
# 1   US        Charleston              SC  United States
# 2   US        Charleston              SC  United States
# 3   US        Charleston              SC  United States
# 4   US      Mt. Pleasant              SC  United States
# 5   US        Charleston              SC  United States
# 6   US  North Charleston              SC  United States
# 7   US      Johns Island              SC  United States
# 8   US       Goose Creek              SC  United States
# 9   US               NaN  South Carolina  United States
# 10  US        Charleston              SC  United States
# 11  US      Mt. Pleasant              SC  United States
# 12  US      Johns Island              SC  United States
# 13  US  North Charleston              SC  United States
# 14  US  North Charleston              SC  United States
# 15  US       Goose Creek              SC  United States
# 16  US        Charleston              SC  United States
# 17  US             Huger              SC  United States
# 18  US       Summerville              SC  United States
# 19  US       Summerville              SC  United States
# 20  US     Moncks Corner              SC  United States
#
#                                      formattedAddress         neighborhood  \
# 0                 [King Street, Charleston, SC 29401]                  NaN
# 1                [235 E Bay St, Charleston, SC 29401]  Downtown Charleston
# 2            [289 Huger Street, Charleston, SC 29403]                  NaN
# 3            [1081 Morrison Dr, Charleston, SC 29403]                  NaN
# 4              [522 Wando Ln, Mt. Pleasant, SC 29464]                  NaN
# 5                              [Charleston, SC 29407]                  NaN
# 6       [2895 Pringle St, North Charleston, SC 29405]                  NaN
# 7          [2863 Maybank Hwy, Johns Island, SC 29455]                  NaN
# 8              [108 Elbow Cir, Goose Creek, SC 29445]                  NaN
# 9                                    [South Carolina]                  NaN
# 10                                   [Charleston, SC]                  NaN
# 11             [510 Ridge Rd, Mt. Pleasant, SC 29464]                  NaN
# 12  [3690 State Rd S-10-1024, Johns Island, SC 29455]                  NaN
# 13  [1250 N 2nd St (Old Navy Base), North Charlest...                  NaN
# 14      [7842 Rivers Ave, North Charleston, SC 29406]                  NaN
# 15                                  [Goose Creek, SC]                  NaN
# 16                                   [Charleston, SC]                  NaN
# 17                [413 Sablewood Dr, Huger, SC 29450]                  NaN
# 18        [108 E 3rd North St, Summerville, SC 29483]                  NaN
# 19                            [Summerville, SC 29483]                  NaN
# 20                                [Moncks Corner, SC]                  NaN
#
#       crossStreet                        id
# 0             NaN  4f0516fc5c5c4a361a4a0668
# 1             NaN  4e02736ee4cdbd9a51747908
# 2             NaN  4dad9006cda1aece4a5b9f1e
# 3             NaN  52e68055498e7ec32a01d706
# 4             NaN  57375ea2498eba786daf2fa2
# 5             NaN  4bae4692f964a520019c3be3
# 6             NaN  523374b611d2af47fc843347
# 7             NaN  56e48850cd10fabb7c13fa05
# 8             NaN  4d72d87d5f0037041289e7a0
# 9             NaN  4d60148e29ef236a59cda059
# 10            NaN  553209fd498e7e82c981e351
# 11            NaN  4d4c814332a3236a11260cea
# 12            NaN  58e8e4c3ebf02879e745aa7c
# 13  Old Navy Base  4bc0cbedabf4952143e6bf93
# 14            NaN  4f32a19d19836c91c7ea9326
# 15            NaN  53ab3acc498ee6657b508362
# 16            NaN  4e8ba988775bb28051f65673
# 17            NaN  53cb54d3498ea26c6f0fadad
# 18            NaN  53f8b283498e4466790c8007
# 19            NaN  4f499908e4b0605e43b724b7
# 20            NaN  55ee162c498e8a2e86a5a1ef

# %%
dfcharleston = dataframe_filtered.groupby("city").count()
dfcharleston
# Out:
#                   name  categories  address  lat  lng  labeledLatLngs  \
# city
# Charleston           7           5        4    7    7               7
# Goose Creek          2           2        1    2    2               2
# Huger                1           1        1    1    1               1
# Johns Island         2           2        2    2    2               2
# Moncks Corner        1           1        0    1    1               1
# Mt. Pleasant         2           2        2    2    2               2
# North Charleston     3           3        3    3    3               3
# Summerville          2           2        1    2    2               2
#
#                   distance  postalCode  cc  state  country  formattedAddress  \
# city
# Charleston               7           5   7      7        7                 7
# Goose Creek              2           1   2      2        2                 2
# Huger                    1           1   1      1        1                 1
# Johns Island             2           2   2      2        2                 2
# Moncks Corner            1           0   1      1        1                 1
# Mt. Pleasant             2           2   2      2        2                 2
# North Charleston         3           3   3      3        3                 3
# Summerville              2           2   2      2        2                 2
#
#                   neighborhood  crossStreet  id
# city
# Charleston                   1            0   7
# Goose Creek                  0            0   2
# Huger                        0            0   1
# Johns Island                 0            0   2
# Moncks Corner                0            0   1
# Mt. Pleasant                 0            0   2
# North Charleston             0            1   3
# Summerville                  0            0   2

# %%
data = [['Goose Creek', 43665, 2, 43665/2], ['Summerville', 52549, 2, 52549/2], ['Charleston', 137566, 7, 137566/7 ], ['James Island', 12109, 0, 12109], ['North Charleston', 115382, 3, 115382/3], ['Mount Pleasant', 91684, 2, 91684/2]] 
  
# Create the pandas DataFrame 
dfpopbrew = pd.DataFrame(data, columns = ['city', 'population', 'breweries', 'popperbrew']) 
dfpopbrew
# Out:
#                city  population  breweries    popperbrew
# 0       Goose Creek       43665          2  21832.500000
# 1       Summerville       52549          2  26274.500000
# 2        Charleston      137566          7  19652.285714
# 3      James Island       12109          0  12109.000000
# 4  North Charleston      115382          3  38460.666667
# 5    Mount Pleasant       91684          2  45842.000000

# %% [markdown]
# As we can see, Mount Pleasant seems to have the highest population per brewery, indicating that Mount Pleasant may have a higher demand for breweries.  Point one for Mount Pleasant.  Now let's visualize everything geographically:

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the center point

# add a red circle marker to represent the random center point
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Center Point',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Breweries as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Let's increase the radius as a quick way to measure the distances between each brewery

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the center point

# add a red circle marker to represent the random center point
folium.CircleMarker(
    [latitude, longitude],
    radius=5,
    color='red',
    popup='Center Point',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Breweries as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.Circle(
        [lat, lng],
        radius=2000,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.2
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# As you can see, it looks like the peninsula is packed.  North Charleston had the second highest population per brewery, but it also appears to have little area that is beyone 2000 meters from the next brewery.  We can see a few empty spots in Mount Pleasant, James Island and West of the Ashley river (West of Charleston).

# %% [markdown]
# ## Let's check out the competition in Mount Pleasant:

# %%
venue_id = '4d4c814332a3236a11260cea' # ID of Westbrook Brewing
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.7

# %%
venue_id = '57375ea2498eba786daf2fa2' # ID of Ghost Monkey
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.2

# %% [markdown]
# ## Hmm... those are pretty good reviews so let's poke around elsewhere. The peninsula seems pretty stacked, so we'll start in North Charleston

# %%
venue_id = '58cc83af9ab6631b5f5b93b8'  #fatty's beer works, pretty decent
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/58cc83af9ab6631b5f5b93b8?client_id=HR2D0FMEQRX3STCPEBUSF22P1Q41XSB4JMPFMJNT54AVYD1O&client_secret=IZYJKTD31AXEE2U2KDQ5GYPYIWRQQL3BX2M21ZMCVVQSDWJS&oauth_token=V0TVPHPZNFARAPF24MUNVC43JN3KZDQGSIMTBVIRQM000TS5&v=20180604'

# %% [markdown]
# #### Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'like', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto'])
# {'id': '58cc83af9ab6631b5f5b93b8',
#  'name': "Fatty's Beer Works",
#  'contact': {'phone': '8439745330',
#   'formattedPhone': '(843) 974-5330',
#   'twitter': 'fattysbeerworks'},
#  'location': {'address': '1436 Meeting Street Rd',
#   'crossStreet': 'Lemon',
#   'lat': 32.81653603235712,
#   'lng': -79.95055139064789,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 32.81653603235712,
#     'lng': -79.95055139064789}],
#   'postalCode': '29405',
#   'cc': 'US',
#   'city': 'Charleston',
#   'state': 'SC',
#   'country': 'United States',
#   'formattedAddress': ['1436 Meeting Street Rd (Lemon)',
#    'Charleston, SC 29405']},
#  'canonicalUrl': 'https://foursquare.com/v/fattys-beer-works/58cc83af9ab6631b5f5b93b8',
#  'categories': [{'id': '50327c8591d4c4b30a586d5d',
#    'name': 'Brewery',
#    'pluralName': 'Breweries',
#    'shortName': 'Brewery',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 1},
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'likes': {'count': 9,
#   'groups': [{'type': 'others',
#     'count': 9,
#     'items': [{'id': '16999799',
#       'firstName': 'Maya',
#       'lastName': 'Byrne',
#       'gender': 'female',
#       'countryCode': 'US',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/16999799-EH3P4V5NRAZNXHPG.jpg'}},
#      {'id': '22826955',
#       'firstName': 'Amanda',
#       'gender': 'female',
#       'countryCode': 'US',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/22826955_bcxs0IjT_lhUW_-GUAaZEysGUwrRnm3GapF-njT-GtEzHlP2LBpXQRphSZhwAYeoOONzE_Ta9.jpg'}},
#      {'id': '1024991',
#       'firstName': 'Robert',
#       'lastName': 'Gleyberman',
#       'gender': 'male',
#       'address': '',
#       'city': '',
#       'state': '',
#       'countryCode': 'US',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/1024991_WYRcDTOO__0zru79-bwGL0V__TxOPY7sm7AWJr_nMIOKuI2_gr_xTvz6ujGuONCnjf6J2WY0W.jpg'}},
#      {'id': '23894800',
#       'firstName': 'Hank',
#       'lastName': 'M.',
#       'gender': 'male',
#       'countryCode': 'US',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/U3JFZY4SK2ZMGKWK.jpg'}}]}],
#   'summary': 'Maya Byrne, Amanda, Robert Gleyberman & 6 others'},
#  'like': False,
#  'dislike': False,
#  'ok': False,
#  'rating': 6.3,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 16,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 26,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 26,
#     'items': [{'id': '5f4ab191235d211f319bc398',
#       'createdAt': 1598730641,
#       'source': {'name': 'Untappd', 'url': 'https://untappd.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/61369992_SbaHpx3GYBgpxB0rFDax4DqIiqnYeyE8GWubS3TXHAM.jpg',
#       'width': 1500,
#       'height': 2000,
#       'user': {'id': '61369992',
#        'firstName': 'Elaine',
#        'lastName': 'Taylor',
#        'gender': 'female',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/RGANP3UYR1YBHRME.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1489798063,
#  'tips': {'count': 1,
#   'groups': [{'type': 'following',
#     'name': 'Tips from people you follow',
#     'count': 0,
#     'items': []},
#    {'type': 'others',
#     'name': 'All tips',
#     'count': 1,
#     'items': [{'id': '5cbbbafe7b385f002c5abb1d',
#       'createdAt': 1555806974,
#       'text': 'Beer is delicious',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5cbbbafe7b385f002c5abb1d',
#       'likes': {'count': 0, 'groups': []},
#       'like': False,
#       'logView': True,
#       'agreeCount': 2,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '13986034',
#        'firstName': 'Rauno',
#        'lastName': 'Reimus',
#        'gender': 'male',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/blank_boy.png',
#         'default': True}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/2nBnJHK',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 6,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 6,
#     'items': [{'id': '5aad782bfd9d7366b999c311',
#       'name': 'Charleston',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '1595325',
#        'firstName': 'G',
#        'gender': 'female',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1595325_bwyc0DSN_v0ebky47_TV8jXzPOtCRQ1eENbUCDm_-JPiW6y41gd0ZLR97479ZmlRkNPqHcPPV.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/1595325/list/charleston',
#       'canonicalUrl': 'https://foursquare.com/user/1595325/list/charleston',
#       'createdAt': 1521317931,
#       'updatedAt': 1608784456,
#       'photo': {'id': '5aa5867667f62b134b1828dd',
#        'createdAt': 1520797302,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/129124371_xZYOJgwsy4VIPhLFoKlR7uuNjzwI3-oVh1a0u3iNPLM.jpg',
#        'width': 1500,
#        'height': 2000,
#        'user': {'id': '129124371',
#         'firstName': 'Harvin',
#         'gender': 'female',
#         'countryCode': 'US',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/blank_girl.png',
#          'default': True}},
#        'visibility': 'public'},
#       'followers': {'count': 0},
#       'listItems': {'count': 30,
#        'items': [{'id': 'v58cc83af9ab6631b5f5b93b8',
#          'createdAt': 1521318134}]}},
#      {'id': '5c27b4600d8a0f002c5eab96',
#       'name': 'todo.charleston',
#       'description': "Places i'd like to check out in Charleston, SC, USA.",
#       'type': 'others',
#       'user': {'id': '63061',
#        'firstName': 'Perry',
#        'lastName': 'Rajnovic',
#        'gender': 'male',
#        'countryCode': 'US',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-WIFRLXXG1JARSQIE.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/psylum/list/todocharleston',
#       'canonicalUrl': 'https://foursquare.com/psylum/list/todocharleston',
#       'createdAt': 1546105952,
#       'updatedAt': 1550098959,
#       'followers': {'count': 0},
#       'listItems': {'count': 76,
#        'items': [{'id': 'v58cc83af9ab6631b5f5b93b8',
#          'createdAt': 1547161956}]}}]}]},
#  'hours': {'status': 'Open until 9:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 9:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Thu',
#     'includesToday': True,
#     'open': [{'renderedTime': '4:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '4:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '2:00 PM–9:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Open until 9:00 PM',
#   'richStatus': {'entities': [], 'text': 'Open until 9:00 PM'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Thu',
#     'includesToday': True,
#     'open': [{'renderedTime': '4:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '4:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '2:00 PM–9:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 7,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Beer',
#     'count': 5,
#     'items': [{'displayName': 'Beer', 'displayValue': 'Beer'}]}]},
#  'bestPhoto': {'id': '5f4ab191235d211f319bc398',
#   'createdAt': 1598730641,
#   'source': {'name': 'Untappd', 'url': 'https://untappd.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/61369992_SbaHpx3GYBgpxB0rFDax4DqIiqnYeyE8GWubS3TXHAM.jpg',
#   'width': 1500,
#   'height': 2000,
#   'visibility': 'public'}}

# %% [markdown]
# ### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.3

# %% [markdown]
# Let's go farther north to check the rating of Edmonds Oast

# %%
venue_id = '52e68055498e7ec32a01d706' # ID of Edmonds Oast
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.3

# %% [markdown]
# That's pretty high, let's dodge that area due to the competition.  Let's go west to Johns Island

# %%
venue_id='56e48850cd10fabb7c13fa05'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET,ACCESS_TOKEN, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.1

# %% [markdown]
# ### At this point, it appears that the best bet is the empty pocket in Mount Pleasant.  Although the two breweries in Mt. Pleasant received high ratings, Mount Pleasant has the highest population per brewery ratio and there is a large spot near downtown that is outside a 2000 meter range from any other brewery.  Let's visualize this to make sure.

# %%
# I obtained this lat and long from eyeballing on google maps
latitude = 32.79287093
longitude = -79.86803579

# %%
#Let's see how that looks if we add it to the prior map
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the center point

# add a red circle marker to represent the random center point
folium.Circle(
    [latitude, longitude],
    radius=2000,
    color='red',
    popup='Proposed Area',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Breweries as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.Circle(
        [lat, lng],
        radius=2000,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.2
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Perfect, the red circle indicates 2000 meters from the proposed sight, and would be an ideal area to open a brewery. But before we make a final decision, let's see what around that area to see what is around that area.

# %% [markdown]
# #### Define URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=HR2D0FMEQRX3STCPEBUSF22P1Q41XSB4JMPFMJNT54AVYD1O&client_secret=IZYJKTD31AXEE2U2KDQ5GYPYIWRQQL3BX2M21ZMCVVQSDWJS&ll=32.79287093,-79.86803579&v=20180604&radius=50000&limit=100'

# %% [markdown]
# #### Send GET request and examine results

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} results around the point of interest.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 100 results around the point of interest.'

# %% [markdown]
# #### Get relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4eab19355c5cf8848a8b31c8',
#   'name': 'Bottles Beverage Superstore',
#   'location': {'address': '610 Coleman Blvd',
#    'crossStreet': 'in Moultrie Plaza Shopping Center',
#    'lat': 32.79178119758284,
#    'lng': -79.87483832936066,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 32.79178119758284,
#      'lng': -79.87483832936066}],
#    'distance': 648,
#    'postalCode': '29464',
#    'cc': 'US',
#    'city': 'Mt. Pleasant',
#    'state': 'SC',
#    'country': 'United States',
#    'formattedAddress': ['610 Coleman Blvd (in Moultrie Plaza Shopping Center)',
#     'Mt. Pleasant, SC 29464',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d186941735',
#     'name': 'Liquor Store',
#     'pluralName': 'Liquor Stores',
#     'shortName': 'Liquor Store',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4eab19355c5cf8848a8b31c8-0'}

# %% [markdown]
# #### Process JSON and convert it to a clean dataframe

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# <ipython-input-30-b7321e367fed>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(items) # flatten JSON
#                                          name      categories  \
# 0                 Bottles Beverage Superstore    Liquor Store
# 1                           Page's Okra Grill           Diner
# 2                      Old Pitt Street Bridge            Park
# 3                    Memorial Waterfront Park            Park
# 4                                Trader Joe's   Grocery Store
# 5                          Whole Foods Market   Grocery Store
# 6      Patriots Point Naval & Maritime Museum  History Museum
# 7                            Five Loaves Cafe            Café
# 8  Coleman Public House Restaurant & Tap Room       Gastropub
# 9                             U.S.S. Yorktown   Boat or Ferry
#
#                       address                        crossStreet        lat  \
# 0            610 Coleman Blvd  in Moultrie Plaza Shopping Center  32.791781
# 1            302 Coleman Blvd                                NaN  32.790697
# 2             957-975 Pitt St                                NaN  32.773218
# 3   Harry M. Hallman Jr. Blvd                                NaN  32.801671
# 4      401 Johnnie Dodds Blvd                                NaN  32.804975
# 5  923 Houston Northcutt Blvd              at Jonnie Dodds Blvd.  32.802583
# 6        40 Patriots Point Rd              Patriots Point Museum  32.790533
# 7     1055 Johnnie Dodds Blvd                                NaN  32.811517
# 8          427 W Coleman Blvd                                NaN  32.795387
# 9        40 Patriots Point Rd                                NaN  32.790330
#
#          lng                                     labeledLatLngs  distance  \
# 0 -79.874838  [{'label': 'display', 'lat': 32.79178119758284...       648
# 1 -79.877168  [{'label': 'display', 'lat': 32.79069716529466...       888
# 2 -79.862881  [{'label': 'display', 'lat': 32.77321827461603...      2240
# 3 -79.903169  [{'label': 'display', 'lat': 32.80167095601691...      3430
# 4 -79.887303  [{'label': 'display', 'lat': 32.80497476857283...      2250
# 5 -79.889303  [{'label': 'display', 'lat': 32.80258267182700...      2264
# 6 -79.905778  [{'label': 'display', 'lat': 32.79053317602629...      3541
# 7 -79.861594  [{'label': 'display', 'lat': 32.81151670112296...      2161
# 8 -79.884247  [{'label': 'display', 'lat': 32.79538690852330...      1542
# 9 -79.908441  [{'label': 'display', 'lat': 32.79032978252765...      3791
#
#   postalCode  cc          city state        country  \
# 0      29464  US  Mt. Pleasant    SC  United States
# 1      29464  US  Mt. Pleasant    SC  United States
# 2      29464  US  Mt. Pleasant    SC  United States
# 3      29464  US  Mt. Pleasant    SC  United States
# 4      29464  US  Mt. Pleasant    SC  United States
# 5      29464  US  Mt. Pleasant    SC  United States
# 6      29464  US  Mt. Pleasant    SC  United States
# 7      29464  US  Mt. Pleasant    SC  United States
# 8      29464  US  Mt. Pleasant    SC  United States
# 9      29464  US  Mt. Pleasant    SC  United States
#
#                                     formattedAddress neighborhood  \
# 0  [610 Coleman Blvd (in Moultrie Plaza Shopping ...          NaN
# 1  [302 Coleman Blvd, Mt. Pleasant, SC 29464, Uni...          NaN
# 2  [957-975 Pitt St, Mt. Pleasant, SC 29464, Unit...          NaN
# 3  [Harry M. Hallman Jr. Blvd, Mt. Pleasant, SC 2...          NaN
# 4  [401 Johnnie Dodds Blvd, Mt. Pleasant, SC 2946...          NaN
# 5  [923 Houston Northcutt Blvd (at Jonnie Dodds B...          NaN
# 6  [40 Patriots Point Rd (Patriots Point Museum),...          NaN
# 7  [1055 Johnnie Dodds Blvd, Mt. Pleasant, SC 294...          NaN
# 8  [427 W Coleman Blvd, Mt. Pleasant, SC 29464, U...          NaN
# 9  [40 Patriots Point Rd, Mt. Pleasant, SC 29464,...          NaN
#
#                          id
# 0  4eab19355c5cf8848a8b31c8
# 1  4e145a1ad22d40141716dbf3
# 2  4b69dd43f964a520f5b82be3
# 3  4b787a83f964a52022d12ee3
# 4  4e13540eb0fbfef99ba26f90
# 5  4b5cbf3ef964a520e94129e3
# 6  4b892891f964a520fc1f32e3
# 7  4c47181b31e41b8d66a24b35
# 8  4c41e742ce54e21e1bc50b1a
# 9  4dd00bfbae603b786d56e02f

# %% [markdown]
# #### Let's visualize these items on the map around our location

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=12) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.Circle(
    [latitude, longitude],
    radius=2000,
    popup='Proposed Area',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.1
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item5"></a>

# %% [markdown]
# ### Nothing too alarming. Let's see if there are any trending venues within the proposed radius

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fecfc7e20e8e9667548428d'},
#  'response': {'venues': []}}

# %% [markdown]
# ### Check if any venues are trending at this time

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# ### Oh well, it was worth a shot. Based on the above analysis, it is clear that the area marked in red is the ideal place to open a brewery near Charleston, SC.
